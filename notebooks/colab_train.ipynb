# %% [markdown]
# # MNIST Colab Training
#
# Upload this project folder to Colab or clone it from GitHub, then prepare MNIST image files, train the model, and create a submission CSV.

# %%
# Option 1: If you use GitHub, run this cell.
REPO_URL = "https://github.com/101543/2026_Navy_AI_Competition_Test1.git"
# !git clone {REPO_URL} project
# %cd project

# %% [markdown]
# If you uploaded the project folder manually, skip the clone cell above and move into your uploaded folder with `%cd your_folder_name`.

# %%
# !pip install -r requirements.txt

# %%
# !python src/prepare_mnist.py --config configs/default.yaml

# %%
# !python src/train.py --config configs/default.yaml

# %%
# !python src/predict.py --config configs/default.yaml --checkpoint outputs/models/best_model.pt

# %% [markdown]
# # MNIST Colab Training
#
# Clone the repository, mount Google Drive, train from PNG image files, and create a submission CSV.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
REPO_URL = "https://github.com/101543/2026_Navy_AI_Competition_Test1.git"
# !git clone {REPO_URL} project
# %cd project

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Option A: Use an existing Drive dataset
#
# Edit `configs/colab_drive.yaml` if your Drive folder name is different. It should point to a folder containing `train.csv`, `val.csv`, `test.csv`, and image folders.

# %%
# !python src/train.py --config configs/colab_drive.yaml

# %%
# !python src/predict.py --config configs/colab_drive.yaml --checkpoint "/content/drive/MyDrive/2026.06.01 AI 학습 코드 파일/outputs/models/best_model.pt"

# %% [markdown]
# ## Option B: Create MNIST image files in Colab
#
# Run these cells instead if the Drive dataset is not prepared yet.

# %%
# !python src/prepare_mnist.py --config configs/default.yaml

# %%
# !python src/train.py --config configs/default.yaml

# %%
# !python src/predict.py --config configs/default.yaml --checkpoint outputs/models/best_model.pt

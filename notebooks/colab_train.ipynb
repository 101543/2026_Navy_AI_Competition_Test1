# %% [markdown]
# # MNIST Colab Training
#
# GitHub에 올린 프로젝트를 Colab에서 clone한 뒤 학습하는 노트북입니다.

# %%
# 본인의 GitHub 저장소 주소로 바꾸세요.
REPO_URL = "https://github.com/YOUR_ID/YOUR_REPOSITORY.git"
# !git clone {REPO_URL} project
# %cd project

# %%
# !pip install -r requirements.txt

# %%
# !python src/train.py --config configs/default.yaml

# %%
# !python src/predict.py --config configs/default.yaml --checkpoint outputs/models/best_model.pt
